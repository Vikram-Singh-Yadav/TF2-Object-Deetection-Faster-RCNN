# %% [markdown]
# ## TensorBoard Events S3 Path

# %%
# tensorboard_s3_output_path = f'{job_artifacts_path}/eval'

tensorboard_s3_output_path = f's3://eagle-eye-dataset/OD_using_TFOD_API/tensorboard/ssd/tf2-object-detection-2021-06-18-02-41-00-395/tensorboard-output/eval'

# %% [markdown]
# ## Run TensorBoard

# %%
# !F_CPP_MIN_LOG_LEVEL=3 AWS_REGION=us-west-2 tensorboard --logdir=$tensorboard_s3_output_path
